# %%
# %matplotlib inline
import sys
sys.path.append('../')
from visualization.viewer import PlotDiar
from utils import loadWAV
import matplotlib.pyplot as plt
import librosa.display
from scipy.io import wavfile
from io import BytesIO
import IPython.display as ipd

# %% [markdown]
# # Test visualization with random data

# %%
wav = loadWAV('../data/voxceleb2/id01026/2mqlB2l76kg/00005.wav', 200, evalmode=False)

# %%
p = PlotDiar(map={
    0: [{'start': 0, 'stop': 100}, {'start': 200, 'stop': 300}], 
    1: [{'start': 100, 'stop': 200}, {'start': 700, 'stop': 1200}],
    2: [{'start': 300, 'stop': 400}, {'start': 1200, 'stop': 1500}],
    3: [{'start': 400, 'stop': 700}]
}, wav=wav)
p.draw()
p.plot.show()

# %% [markdown]
# # Visualization of dataset

# %%
from dataset.voxceleb_dataset import VoxCelebDataset

# %%
dataset = VoxCelebDataset("../data/train_list.txt", 
                          True, 
                          "../data/musan_split", 
                          "../data/RIRS_NOISES/simulated_rirs", 
                          200, 
                          "../data/voxceleb2")

# %%
features, label = dataset[11000]

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(features.numpy()[0], sr=16000)

# %%
ipd.Audio(features.numpy()[0], rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
